# %%
import json

file_path = "/Users/rachanareddy/Downloads/titanic.json"

# Read the local JSON file
with open(file_path, "r") as f:
    data = json.load(f)

print("Local JSON Data:")
print(data)
# Out:
# Local JSON Data:
# {'name': 'Rachana', 'role': 'Senior Data Engineer', 'skills': ['Python', 'SQL', 'Snowflake', 'AWS', 'Azure']}

# %%
import requests

url = "http://127.0.0.1:5000/rachana/project"
response = requests.get(url)

print("Status:", response.status_code)
print("Text:", response.text)
# Out:
# Status: 200
# Text: {"description":"Rachana is building a cloud-based data pipeline using Python and Snowflake.","name":"Data Engineering Pipeline","projectId":202,"status":"In Progress"}
